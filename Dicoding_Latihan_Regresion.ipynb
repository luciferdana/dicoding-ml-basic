# %% [markdown]
# #Data Load

# %%
import pandas as pd

df_train = pd.read_csv("/content/train.csv")
df_train
# Out:
#             id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0            0                 5                   8                5
# 1            1                 6                   7                4
# 2            2                 6                   5                6
# 3            3                 3                   4                6
# 4            4                 5                   3                2
# ...        ...               ...                 ...              ...
# 180547  180547                 7                   3                3
# 180548  180548                 4                   4                5
# 180549  180549                 4                   5                8
# 180550  180550                 3                   3                3
# 180551  180551                 6                   8                5
#
#         Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0                   8           6.0            4.0          4.0        3.0
# 1                   4           8.0            8.0          3.0        5.0
# 2                   7           3.0            7.0          1.0        5.0
# 3                   5           4.0            8.0          4.0        7.0
# 4                   6           4.0            4.0          3.0        3.0
# ...               ...           ...            ...          ...        ...
# 180547              7           7.0            3.0          5.0        3.0
# 180548              4           2.0            6.0          5.0        5.0
# 180549              8           9.0            6.0          7.0        3.0
# 180550              9           7.0            5.0          5.0        8.0
# 180551             10           NaN            NaN          NaN        NaN
#
#         AgriculturalPractices  ...  DrainageSystems  CoastalVulnerability  \
# 0                         3.0  ...              5.0                   3.0
# 1                         4.0  ...              7.0                   2.0
# 2                         4.0  ...              7.0                   3.0
# 3                         6.0  ...              2.0                   4.0
# 4                         3.0  ...              2.0                   2.0
# ...                       ...  ...              ...                   ...
# 180547                    5.0  ...              6.0                   6.0
# 180548                    6.0  ...              6.0                   6.0
# 180549                    6.0  ...              6.0                   5.0
# 180550                    2.0  ...              4.0                   6.0
# 180551                    NaN  ...              NaN                   NaN
#
#         Landslides  Watersheds  DeterioratingInfrastructure  PopulationScore  \
# 0              3.0         5.0                          4.0              7.0
# 1              0.0         3.0                          5.0              3.0
# 2              7.0         5.0                          6.0              8.0
# 3              7.0         4.0                          4.0              6.0
# 4              6.0         6.0                          4.0              1.0
# ...            ...         ...                          ...              ...
# 180547         3.0         3.0                          2.0              4.0
# 180548         8.0         3.0                          5.0              5.0
# 180549         7.0         5.0                          9.0              5.0
# 180550         2.0         4.0                          4.0              0.0
# 180551         NaN         NaN                          NaN              NaN
#
#         WetlandLoss  InadequatePlanning  PoliticalFactors  FloodProbability
# 0               5.0                 7.0               3.0             0.445
# 1               3.0                 4.0               3.0             0.450
# 2               2.0                 3.0               3.0             0.530
# 3               5.0                 7.0               5.0             0.535
# 4               2.0                 3.0               5.0             0.415
# ...             ...                 ...               ...               ...
# 180547          6.0                 9.0               6.0             0.475
# 180548          7.0                 3.0               5.0             0.530
# 180549          7.0                 8.0               6.0             0.645
# 180550          9.0                 2.0               4.0             0.435
# 180551          NaN                 NaN               NaN               NaN
#
# [180552 rows x 22 columns]

# %%
df_test = pd.read_csv("/content/test.csv")
df_test
# Out:
#              id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# 0       1117957                 4                   6                3
# 1       1117958                 4                   4                2
# 2       1117959                 1                   3                6
# 3       1117960                 2                   4                4
# 4       1117961                 6                   3                2
# ...         ...               ...                 ...              ...
# 194829  1312786                 3                   4                5
# 194830  1312787                 7                   8                4
# 194831  1312788                 6                   4                6
# 194832  1312789                 7                   5                6
# 194833  1312790                 8                   7                3
#
#         Deforestation  Urbanization  ClimateChange  DamsQuality  Siltation  \
# 0                   5             6              7            8          7
# 1                   9             5              5            4          7
# 2                   5             7              2            4          6
# 3                   6             4              5            4          3
# 4                   4             6              4            5          5
# ...               ...           ...            ...          ...        ...
# 194829              3             7              4            3          4
# 194830              3             4              2            4          4
# 194831              4             4              5            4          6
# 194832              5             5              4            6          3
# 194833              8             2              4            5          6
#
#         AgriculturalPractices  ...  IneffectiveDisasterPreparedness  \
# 0                           8  ...                                8
# 1                           5  ...                                2
# 2                           4  ...                                7
# 3                           4  ...                                7
# 4                           3  ...                                4
# ...                       ...  ...                              ...
# 194829                      7  ...                                7
# 194830                      5  ...                                3
# 194831                      5  ...                                7
# 194832                      9  ...                                9
# 194833                      3  ...                                8
#
#         DrainageSystems  CoastalVulnerability  Landslides  Watersheds  \
# 0                   5.0                   7.0         5.0         6.0
# 1                   4.0                   7.0         4.0         5.0
# 2                   9.0                   2.0         5.0         5.0
# 3                   8.0                   4.0         6.0         7.0
# 4                   3.0                   2.0         6.0         4.0
# ...                 ...                   ...         ...         ...
# 194829              6.0                   7.0         8.0         2.0
# 194830              2.0                   3.0         3.0         5.0
# 194831              7.0                   5.0         4.0         5.0
# 194832              5.0                   6.0         9.0         5.0
# 194833              NaN                   NaN         NaN         NaN
#
#         DeterioratingInfrastructure  PopulationScore  WetlandLoss  \
# 0                               3.0              6.0          4.0
# 1                               1.0              7.0          4.0
# 2                               2.0              3.0          6.0
# 3                               6.0              4.0          2.0
# 4                               6.0              8.0          4.0
# ...                             ...              ...          ...
# 194829                          7.0              8.0          3.0
# 194830                          5.0              3.0          5.0
# 194831                          6.0              4.0          2.0
# 194832                          5.0              6.0          5.0
# 194833                          NaN              NaN          NaN
#
#         InadequatePlanning  PoliticalFactors
# 0                      4.0               5.0
# 1                      4.0               3.0
# 2                      8.0               3.0
# 3                      4.0               4.0
# 4                      5.0               5.0
# ...                    ...               ...
# 194829                 5.0               6.0
# 194830                 2.0               5.0
# 194831                10.0               9.0
# 194832                 5.0               5.0
# 194833                 NaN               NaN
#
# [194834 rows x 21 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180552 entries, 0 to 180551
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   id                               180552 non-null  int64
#  1   MonsoonIntensity                 180552 non-null  int64
#  2   TopographyDrainage               180552 non-null  int64
#  3   RiverManagement                  180552 non-null  int64
#  4   Deforestation                    180552 non-null  int64
#  5   Urbanization                     180551 non-null  float64
#  6   ClimateChange                    180551 non-null  float64
#  7   DamsQuality                      180551 non-null  float64
#  8   Siltation                        180551 non-null  float64
#  9   AgriculturalPractices            180551 non-null  float64
#  10  Encroachments                    180551 non-null  float64
#  11  IneffectiveDisasterPreparedness  180551 non-null  float64
#  12  DrainageSystems                  180551 non-null  float64
#  13  CoastalVulnerability             180551 non-null  float64
#  14  Landslides                       180551 non-null  float64
#  15  Watersheds                       180551 non-null  float64
#  16  DeterioratingInfrastructure      180551 non-null  float64
#  17  PopulationScore                  180551 non-null  float64
#  18  WetlandLoss                      180551 non-null  float64
#  19  InadequatePlanning               180551 non-null  float64
#  20  PoliticalFactors                 180551 non-null  float64
#  21  FloodProbability                 180551 non-null  float64
# dtypes: float64(17), int64(5)
# memory usage: 30.3 MB

# %%
df_train.describe(include="all")
# Out:
#                   id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  180552.000000     180552.000000       180552.000000    180552.000000
# mean    90275.500000          4.920555            4.935969         4.959225
# std     52121.017239          2.056138            2.098497         2.071897
# min         0.000000          0.000000            0.000000         0.000000
# 25%     45137.750000          3.000000            3.000000         4.000000
# 50%     90275.500000          5.000000            5.000000         5.000000
# 75%    135413.250000          6.000000            6.000000         6.000000
# max    180551.000000         16.000000           17.000000        16.000000
#
#        Deforestation   Urbanization  ClimateChange    DamsQuality  \
# count  180552.000000  180551.000000  180551.000000  180551.000000
# mean        4.944487       4.939790       4.929975       4.952102
# std         2.049974       2.080739       2.061819       2.085529
# min         0.000000       0.000000       0.000000       0.000000
# 25%         4.000000       3.000000       3.000000       4.000000
# 50%         5.000000       5.000000       5.000000       5.000000
# 75%         6.000000       6.000000       6.000000       6.000000
# max        16.000000      17.000000      16.000000      16.000000
#
#            Siltation  AgriculturalPractices  ...  DrainageSystems  \
# count  180551.000000          180551.000000  ...    180551.000000
# mean        4.930158               4.947051  ...         4.945628
# std         2.073540               2.065290  ...         2.066522
# min         0.000000               0.000000  ...         0.000000
# 25%         3.000000               4.000000  ...         4.000000
# 50%         5.000000               5.000000  ...         5.000000
# 75%         6.000000               6.000000  ...         6.000000
# max        16.000000              16.000000  ...        17.000000
#
#        CoastalVulnerability     Landslides     Watersheds  \
# count         180551.000000  180551.000000  180551.000000
# mean               4.951864       4.926530       4.924481
# std                2.089361       2.077014       2.085735
# min                0.000000       0.000000       0.000000
# 25%                3.000000       3.000000       3.000000
# 50%                5.000000       5.000000       5.000000
# 75%                6.000000       6.000000       6.000000
# max               17.000000      16.000000      16.000000
#
#        DeterioratingInfrastructure  PopulationScore    WetlandLoss  \
# count                180551.000000    180551.000000  180551.000000
# mean                      4.924326         4.926724       4.945572
# std                       2.069615         2.076553       2.067327
# min                       0.000000         0.000000       0.000000
# 25%                       3.000000         3.000000       3.000000
# 50%                       5.000000         5.000000       5.000000
# 75%                       6.000000         6.000000       6.000000
# max                      17.000000        18.000000      17.000000
#
#        InadequatePlanning  PoliticalFactors  FloodProbability
# count       180551.000000     180551.000000     180551.000000
# mean             4.941435          4.935797          0.504384
# std              2.079389          2.090044          0.050996
# min              0.000000          0.000000          0.285000
# 25%              3.000000          3.000000          0.470000
# 50%              5.000000          5.000000          0.505000
# 75%              6.000000          6.000000          0.540000
# max             16.000000         16.000000          0.725000
#
# [8 rows x 22 columns]

# %% [markdown]
# #Preprocessing Data

# %%
missing_values = df_train.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Urbanization                       1
# ClimateChange                      1
# DamsQuality                        1
# Siltation                          1
# AgriculturalPractices              1
# Encroachments                      1
# IneffectiveDisasterPreparedness    1
# DrainageSystems                    1
# CoastalVulnerability               1
# Landslides                         1
# Watersheds                         1
# DeterioratingInfrastructure        1
# PopulationScore                    1
# WetlandLoss                        1
# InadequatePlanning                 1
# PoliticalFactors                   1
# FloodProbability                   1
# dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

for feature in df_train.columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df_train[feature])
    plt.title(f'Box Plot of {feature}')
    plt.show()

# %%
# Contoh sederhana untuk mengidentifikasi outliers menggunakan IQR
Q1 = df_train.quantile(0.25)
Q3 = df_train.quantile(0.75)
IQR = Q3 - Q1
# Filter dataframe untuk hanya menyimpan baris yang tidak mengandung outliers pada kolom numerik
condition = ~((df_train < (Q1 - 1.5 * IQR)) | (df_train > (Q3 + 1.5 * IQR))).any(axis=1)
df = df_train.loc[condition, df_train.columns]

# %%
from sklearn.preprocessing import StandardScaler

# Memastikan hanya data dengan tipe numerikal yang akan diproses
numeric_features = df.select_dtypes(include=['number']).columns
numeric_features

# Standardisasi fitur numerik
scaler = StandardScaler()
df[numeric_features] = scaler.fit_transform(df[numeric_features])

# %%
# Mengidentifikasi baris duplikat
duplicates = df.duplicated()

print("Baris duplikat:")
print(df[duplicates])
# Out:
# Baris duplikat:
# Empty DataFrame
# Columns: [id, MonsoonIntensity, TopographyDrainage, RiverManagement, Deforestation, Urbanization, ClimateChange, DamsQuality, Siltation, AgriculturalPractices, Encroachments, IneffectiveDisasterPreparedness, DrainageSystems, CoastalVulnerability, Landslides, Watersheds, DeterioratingInfrastructure, PopulationScore, WetlandLoss, InadequatePlanning, PoliticalFactors, FloodProbability]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.describe(include='all')
# Out:
#                  id  MonsoonIntensity  TopographyDrainage  RiverManagement  \
# count  1.392070e+05      1.392070e+05        1.392070e+05     1.392070e+05
# mean  -1.176012e-16      5.479377e-17        1.888560e-16    -1.123949e-16
# std    1.000004e+00      1.000004e+00        1.000004e+00     1.000004e+00
# min   -1.734687e+00     -2.498079e+00       -2.446191e+00    -2.066512e+00
# 25%   -8.630597e-01     -4.518824e-01       -9.500359e-01    -4.680864e-01
# 50%   -6.079009e-04      5.966670e-02        4.740095e-02     6.472228e-02
# 75%    8.663166e-01      5.712158e-01        5.461194e-01     5.975310e-01
# max    1.731168e+00      2.617412e+00        2.540993e+00     2.195957e+00
#
#        Deforestation  Urbanization  ClimateChange   DamsQuality     Siltation  \
# count   1.392070e+05  1.392070e+05   1.392070e+05  1.392070e+05  1.392070e+05
# mean   -1.369972e-16 -1.300554e-16   9.182486e-17 -1.143345e-16  2.344367e-16
# std     1.000004e+00  1.000004e+00   1.000004e+00  1.000004e+00  1.000004e+00
# min    -2.082445e+00 -2.476143e+00  -2.492253e+00 -2.057447e+00 -2.482084e+00
# 25%    -4.695384e-01 -4.600589e-01  -4.579000e-01 -4.628315e-01 -4.550926e-01
# 50%     6.809706e-02  4.396203e-02   5.068820e-02  6.870707e-02  5.165509e-02
# 75%     6.057325e-01  5.479830e-01   5.592764e-01  6.002457e-01  5.584028e-01
# max     2.218639e+00  2.564067e+00   2.593629e+00  2.194861e+00  2.585394e+00
#
#        AgriculturalPractices  ...  DrainageSystems  CoastalVulnerability  \
# count           1.392070e+05  ...     1.392070e+05          1.392070e+05
# mean           -4.185458e-17  ...    -1.559849e-16         -7.646117e-17
# std             1.000004e+00  ...     1.000004e+00          1.000004e+00
# min            -2.063544e+00  ...    -2.070093e+00         -2.471066e+00
# 25%            -4.659938e-01  ...    -4.639473e-01         -4.623202e-01
# 50%             6.652300e-02  ...     7.143449e-02          3.986627e-02
# 75%             5.990398e-01  ...     6.068163e-01          5.420528e-01
# max             2.196590e+00  ...     2.212962e+00          2.550799e+00
#
#          Landslides    Watersheds  DeterioratingInfrastructure  \
# count  1.392070e+05  1.392070e+05                 1.392070e+05
# mean  -1.539432e-16  2.218293e-16                -2.035817e-16
# std    1.000004e+00  1.000004e+00                 1.000004e+00
# min   -2.462869e+00 -2.459101e+00                -2.479591e+00
# 25%   -9.549652e-01 -9.545652e-01                -9.589120e-01
# 50%    5.030428e-02  4.845905e-02                 5.487425e-02
# 75%    5.529390e-01  5.499712e-01                 5.617674e-01
# max    2.563478e+00  2.556020e+00                 2.589340e+00
#
#        PopulationScore   WetlandLoss  InadequatePlanning  PoliticalFactors  \
# count     1.392070e+05  1.392070e+05        1.392070e+05      1.392070e+05
# mean      7.452157e-18  7.676742e-17       -2.070270e-16      1.263804e-16
# std       1.000004e+00  1.000004e+00        1.000004e+00      1.000004e+00
# min      -2.476446e+00 -2.491431e+00       -2.469085e+00     -2.460429e+00
# 25%      -4.537209e-01 -4.649617e-01       -9.620966e-01     -9.564334e-01
# 50%       5.196051e-02  4.165553e-02        4.256234e-02      4.623042e-02
# 75%       5.576419e-01  5.482728e-01        5.448918e-01      5.475623e-01
# max       2.580367e+00  2.574742e+00        2.554210e+00      2.552890e+00
#
#        FloodProbability
# count      1.392070e+05
# mean       1.158861e-15
# std        1.000004e+00
# min       -2.760943e+00
# 25%       -7.151272e-01
# 50%        9.082259e-04
# 75%        7.169436e-01
# max        2.967341e+00
#
# [8 rows x 22 columns]

# %%
# Menghitung jumlah variabel
num_vars = df.shape[1]

# Menentukan jumlah baris dan kolom untuk grid subplot
n_cols = 4  # Jumlah kolom yang diinginkan
n_rows = -(-num_vars // n_cols)  # Ceiling division untuk menentukan jumlah baris

# Membuat subplot
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 4))

# Flatten axes array untuk memudahkan iterasi jika diperlukan
axes = axes.flatten()

# Plot setiap variabel
for i, column in enumerate(df.columns):
    df[column].hist(ax=axes[i], bins=20, edgecolor='black')
    axes[i].set_title(column)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

# Menghapus subplot yang tidak terpakai (jika ada)
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

# Menyesuaikan layout agar lebih rapi
plt.tight_layout()
plt.show()

# %%
# Menghitung korelasi antara variabel target dan semua variabel lainnya
target_corr = df.corr()['FloodProbability']

# (Opsional) Mengurutkan hasil korelasi berdasarkan kekuatan korelasi
target_corr_sorted = target_corr.abs().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
target_corr_sorted.plot(kind='bar')
plt.title(f'Correlation with SalePrice')
plt.xlabel('Variables')
plt.ylabel('Correlation Coefficient')
plt.show()

# %% [markdown]
# #Data Splitting

# %%
import sklearn
from sklearn import datasets

# Memisahkan fitur (X) dan target (y)
X = df.drop(columns=['FloodProbability'])
y = df['FloodProbability']

from sklearn.model_selection import train_test_split

# membagi dataset menjadi training dan testing
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# menghitung panjang/jumlah data
print("Jumlah data: ",len(X))
# menghitung panjang/jumlah data pada x_test
print("Jumlah data latih: ",len(x_train))
# menghitung panjang/jumlah data pada x_test
print("Jumlah data test: ",len(x_test))
# Out:
# Jumlah data:  139207
# Jumlah data latih:  111365
# Jumlah data test:  27842

# %% [markdown]
# #Pembangunan Model

# %% [markdown]
# Menggunakan LARS

# %%
from sklearn import linear_model
lars = linear_model.Lars(n_nonzero_coefs=1).fit(x_train, y_train)

pred_lars = lars.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae_lars = mean_absolute_error(y_test, pred_lars)
mse_lars = mean_squared_error(y_test, pred_lars)
r2_lars = r2_score(y_test, pred_lars)

print(f"MAE: {mae_lars}")
print(f"MSE: {mse_lars}")
print(f"R²: {r2_lars}")
# Out:
# MAE: 0.8068629984039949
# MSE: 1.0013850776460769
# R²: 0.0010263941571261315

# %%
# Membuat dictionary untuk menyimpan hasil evaluasi
data = {
    'MAE': [mae_lars],
    'MSE': [mse_lars],
    'R2': [r2_lars]
}

# Konversi dictionary menjadi DataFrame
df_results = pd.DataFrame(data, index=['Lars'])
df_results
# Out:
#            MAE       MSE        R2
# Lars  0.806863  1.001385  0.001026

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression().fit(x_train, y_train)

pred_LR = LR.predict(x_test)

mae_LR = mean_absolute_error(y_test, pred_LR)
mse_LR = mean_squared_error(y_test, pred_LR)
r2_LR = r2_score(y_test, pred_LR)

print(f"MAE: {mae_LR}")
print(f"MSE: {mse_LR}")
print(f"R²: {r2_LR}")
# Out:
# MAE: 0.32663521861082767
# MSE: 0.16903217091814515
# R²: 0.8313748815965193

# %%
df_results.loc['Linear Regression'] = [mae_LR, mse_LR, r2_LR]
df_results
# Out:
#                         MAE       MSE        R2
# Lars               0.806863  1.001385  0.001026
# Linear Regression  0.326635  0.169032  0.831375

# %% [markdown]
# Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

GBR = GradientBoostingRegressor(random_state=184)
GBR.fit(x_train, y_train)

pred_GBR = GBR.predict(x_test)

mae_GBR = mean_absolute_error(y_test, pred_GBR)
mse_GBR = mean_squared_error(y_test, pred_GBR)
r2_GBR = r2_score(y_test, pred_GBR)

print(f"MAE: {mae_GBR}")
print(f"MSE: {mse_GBR}")
print(f"R²: {r2_GBR}")
# Out:
# MAE: 0.5130402098616248
# MSE: 0.3819537933385744
# R²: 0.6189660034741837

# %%
df_results.loc['GradientBoostingRegressor'] = [mae_GBR, mse_GBR, r2_GBR]
df_results
# Out:
#                                 MAE       MSE        R2
# Lars                       0.806863  1.001385  0.001026
# Linear Regression          0.326635  0.169032  0.831375
# GradientBoostingRegressor  0.513040  0.381954  0.618966
